# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmettalhabektas/how-can-you-make-up-your-data-part-2?scriptVersionId=111742840" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # How can you make up your data? (Part-2)

# %% [markdown]
# ![](https://miro.medium.com/max/1400/0*GDs1G5ixcp5mxEvu) Photo by [Amy Shamblen](https://unsplash.com/@amyshamblen?utm_source=medium&utm_medium=referral) on [Unsplash](https://unsplash.com/?utm_source=medium&utm_medium=referral)

# %% [markdown]
# - [Article of first part](https://medium.com/mlearning-ai/how-can-you-make-up-your-data-part-1-f156ce49c03f)
# - [Notebook of first part](https://www.kaggle.com/code/ahmettalhabektas/how-can-you-make-up-your-data-part-1)

# %% [markdown]
# ## Data Visualization by Seaborn

# %% [markdown]
# - [Article of this notebook](https://medium.com/@ahmettalhabektas/how-can-you-make-up-your-data-part-2-1bcb985d7d4a).

# %% [markdown]
# #### Table of contents:
# - **Importing Libraries**
# - **EDA**
# - **lineplot**
# - **scatterplot**
# - **histplot**
# - **displot**
# - **boxplot**
# - **countplot**
# - **barplot**
# - **heatmap**
# - **pairplot**
# - **Conclusion**

# %% [markdown]
# > # **Importing Libraries**

# %%
import matplotlib.pyplot as plt
#We imported matplotlib as "plt".
# %matplotlib inline
import seaborn as sns
#We imported seaborn as "sns".

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# > # **EDA**

# %% [markdown]
# If you don’t know “EDA”, I highly recommend you to read [this article](https://medium.com/mlearning-ai/our-new-friend-is-eda-ad8acb779432) or [this notebook](https://www.kaggle.com/code/ahmettalhabektas/our-new-friend-is-eda).
#
# If you want to learn more about filtering data, you should read [this article](https://medium.com/mlearning-ai/may-i-take-a-filtering-data-cdea0d49a99d) or [this notebook](https://www.kaggle.com/code/ahmettalhabektas/may-i-take-a-filtering-data).

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 717         1       2  female  27.0      0      0  10.5000        S  Second
# 353         0       3    male  25.0      1      0  17.8000        S   Third
# 212         0       3    male  22.0      0      0   7.2500        S   Third
# 844         0       3    male  17.0      0      0   8.6625        S   Third
# 52          1       1  female  49.0      1      0  76.7292        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 717  woman       False    E  Southampton   yes   True
# 353    man        True  NaN  Southampton    no  False
# 212    man        True  NaN  Southampton    no   True
# 844    man        True  NaN  Southampton    no   True
# 52   woman       False    D    Cherbourg   yes  False

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 891 entries, 0 to 890
#
# Data columns (total 15 columns):
#
#  #   Column       Non-Null Count  Dtype
#
# ---  ------       --------------  -----
#
#  0   survived     891 non-null    int64
#
#  1   pclass       891 non-null    int64
#
#  2   sex          891 non-null    object
#
#  3   age          714 non-null    float64
#
#  4   sibsp        891 non-null    int64
#
#  5   parch        891 non-null    int64
#
#  6   fare         891 non-null    float64
#
#  7   embarked     889 non-null    object
#
#  8   class        891 non-null    category
#
#  9   who          891 non-null    object
#
#  10  adult_male   891 non-null    bool
#
#  11  deck         203 non-null    category
#
#  12  embark_town  889 non-null    object
#
#  13  alive        891 non-null    object
#
#  14  alone        891 non-null    bool
#
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
#
# memory usage: 80.7+ KB

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# I haven't shown you how to fill in empty data; thus, I will not empty age data.

# %%
titanic_full_age=titanic[titanic["age"].notnull()]

# %%
titanic_full_age.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           530
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# > # **lineplot**

# %%
sns.lineplot(data=titanic_full_age[["age","fare"]])
#We said graph a line plot and the data is "titanic_full_age" 
#and also give 2 columns and it puts automatically on the x-axis.
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=titanic_full_age,x="age",y="fare");
#Our data is "titanic_full_age" 

#Put "age" column values on the x-axis.

#Put "fare" column values on the y-axis.

#In addition if you put ";" at the end of the code,
#you will not see something like "<AxesSubplot:xlabel='age', ylabel='fare'>"

# %%
sns.set_style("darkgrid")
#You can also use whitegrid, dark, white, ticks  instead of darkgrid.

# %%
sns.lineplot(data=titanic_full_age,x="age",y="fare");

# %%
sns.set_style("whitegrid")

# %%
sns.lineplot(data=titanic_full_age[["age","fare"]]);

# %%
sns.set_style("white")
#Cleaning the style of graph.

# %% [markdown]
# > # **scatterplot**

# %%
sns.scatterplot(x="age",y="fare",hue="survived",data=titanic_full_age);
#Create a scatter plot with regard to the "survived" column

# %% [markdown]
# > # **histplot**

# %%
sns.histplot(data=titanic_full_age, x="who");
#Create a histogram put "who" column values on the x-axis.

# %%
sns.histplot(data=titanic_full_age, y="who", fill=False);
#Create a histogram and put "who" column values on the y-axis.
#Do not fill the inside of rectangles!

# %%
sns.histplot(data=titanic_full_age, x="who",kde=True);
#kde=kernel density estimate
#We can easily see the distribution by "kde"

# %%
sns.histplot(data=titanic_full_age, x="pclass", hue="survived");
#We can also compare elements in contrast to a column. 
#In this case, we compare "pclass"  column values in contrast to the "survived" column.

# %% [markdown]
# However, When blue and orange overlap, we see **black**.

# %%
sns.histplot(data=titanic_full_age, x="pclass", hue="survived",multiple="stack");
#You can use multiple="stack" attributes or...

# %%
sns.histplot(data=titanic_full_age, x="pclass", hue="survived", element="step");
# element="step" attributes.

# %% [markdown]
# > # **displot**

# %% [markdown]
# ###### it is very similar to the histplot

# %%
sns.displot(titanic_full_age.age,bins=10,kde=True);
#"bins=n" means show us the number of rectangles "n" in the graph.

# %%
sns.displot(titanic_full_age.age,bins=50,kde=True);

# %% [markdown]
# > # **boxplot**

# %%
sns.boxplot(x="age",y="sex",data=titanic_full_age,hue="survived");
#Creating a boxplot

# %% [markdown]
# > # **countplot**

# %%
sns.countplot(x=titanic_full_age.embarked);
#It is aotumaticly counting values. You don't need to write ".value_counts()"

# %%
sns.countplot(y=titanic_full_age.embarked);
#Without giving data attiributes

# %%
sns.countplot(x=titanic_full_age.embarked,hue=(titanic_full_age["survived"]));

# %% [markdown]
# > # **barplot**

# %%
sns.barplot(data=titanic_full_age, x="pclass", y="age");
#creating a bar plot

# %%
sns.barplot(data=titanic_full_age, x="pclass", y="age",hue="survived");

# %% [markdown]
# > **heatmap**

# %%
sns.heatmap(titanic_full_age.corr(), annot = True);
#You should give a correlation inside this graph.
#annot=True means show the numbers of correlation in the squares

# %%
sns.heatmap(titanic_full_age.corr(), annot = False,cmap="crest");
#annot=False means do not show numbers inside of squares
#cmap=colour map

# %% [markdown]
# > # **pairplot**

# %%
sns.pairplot(titanic, hue="survived");
#Creating a pair plot.

plt.savefig("titanic.png",dpi=300)
#saving graph by matplotlib

# %%
sns.pairplot(titanic, hue="survived", kind="kde");
#It is automatically crating scatterplot but 
#if you want change, you can by "kind" method.

#You can use ['scatter', 'kde', 'hist', 'reg'] by kind.

plt.savefig("titanic_kde.png",dpi=300)

# %% [markdown]
# > # Conculusion

# %% [markdown]
# Data visualization is one of the crucial things for a Data Scientist. You have learned how to present your data by graphs with these two parts. I hope you enjoyed😊

# %% [markdown]
# **Author :**
# # Ahmet Talha Bektaş
# **If you want to ask anything to me, you can easily contact with me!**
#
# **👉Shoot me emails: ahmetnvshr04@gmail.com**
#
# **👉Connect on LinkedIn: https://www.linkedin.com/in/ahmet-talha-bekta%C5%9F-056844216**
#
# **👉Explore Github: https://github.com/ahmettalhabektas**
#
# **👉Folow me in Medium: https://medium.com/@ahmettalhabektas**
